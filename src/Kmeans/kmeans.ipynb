# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

veriler = pd.read_csv("musteriler.csv")


X = veriler.iloc[:,3:4]

from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=3,init= "k-means++")
kmeans.fit(X)

print(kmeans.cluster_centers_)
# Out:
# [[ 59456.06060606]
#  [104386.95652174]
#  [ 22706.81818182]]

# %%
sonuclar = []


for i in range (1,11):
    kmeans = KMeans(n_clusters= i, init= "k-means++", random_state=123)
    kmeans.fit(X)
    sonuclar.append(kmeans.inertia_)
print(sonuclar)
plt.plot(range(1,11),sonuclar)
# Out:
# [241761365950.0, 68604558741.31944, 36913960277.49361, 19273833522.590767, 12454460431.705778, 8162779572.00694, 6646179369.308469, 4889923977.633478, 3799317946.3011446, 2859965093.3706813]
